# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmuh/harishmuh/blob/main/Python_Variable_Data_Type_and_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Variable, Data Type and Operator**

# %% [markdown]
# ## Numeric : Integer & float data types

# %%
# Providing value to variable x

x = 5

# %%
# checking the data type of variable x
type(x)
# Out:
# int

# %%
y = 3.14

# %%
# checking the data type of variable y
type(y)
# Out:
# float

# %%
# Addition
x + y
# Out:
# 8.14

# %%
# Substraction
x - y
# Out:
# 1.8599999999999999

# %%
# Multiplication
x * y
# Out:
# 15.700000000000001

# %%
a = 10
b = 3

# %%
# Division
a / b
# Out:
# 3.3333333333333335

# %%
# Divison and rounddown # Floor division
a // b
# Out:
# 3

# %%
# Modulus
a % b
# Out:
# 1

# %%
# negation
-a
# Out:
# -10

# %%
# Exponentiation
a ** b
# Out:
# 1000

# %% [markdown]
# ## Boolean data type

# %%
# Bolean data consist of True and False. Use of capital 'T'
True
# Out:
# True

# %%
# How to write False
False
# Out:
# False

# %%
# There will be a NameError without capital
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ed585c880bfa> in <cell line: 2>()
#       1 # There will be a NameError without capital
# ----> 2 true
#
# NameError: name 'true' is not defined

# %%
# The relationship between conditions and operators (and)
True and True

# %%
True and False

# %%
False and False

# %%
# Example of condition
# Someone will get a job if she/he has qualifications and skills
is_qualifications = True
is_upgrade_skills = True

get_job = is_qualifications and is_upgrade_skills

get_job
# Out:
# True

# %%
# The relationship between conditions and operators (or)
True or True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
# Case: someone can be considered as a science student if he/she enroll in mathematics or life sciences

is_matemathics = True
is_life_sciences = False

is_science = is_matemathics or is_life_sciences

is_science
# Out:
# True

# %%
# Testing boolean operation # biner concept (True = 1, False=0)
True + True
# Out:
# 2

# %%
True - True
# Out:
# 0

# %%
False + False
# Out:
# 0

# %%
False + True
# Out:
# 1

# %%
3 * False
# Out:
# 0

# %%
3 * True
# Out:
# 3

# %%
3 ** True # Exponentiation of 1
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
int(True) # Converting boolean into integer
# Out:
# 1

# %%
type(int(True))
# Out:
# int

# %%
int(False)
# Out:
# 0

# %% [markdown]
# ## Comparison operator

# %%
# Comparison operations involve operators:
# > more than
# < less than
# >= greater than or equal to
# <= less than or equal to
# == equals
# != not equal to
# comparison operation will return True or False

# %%
# Providing value to variables
a = 3
b = 4

# %%
a
# Out:
# 3

# %%
b
# Out:
# 4

# %%
# Greater than
a > b
# Out:
# False

# %%
# Less than
a < b
# Out:
# True

# %%
# confirming of equality in value
a == 5
# Out:
# False

# %%
# not equal to
a != b
# Out:
# True

# %% [markdown]
# ## String data type

# %%
# String must be followed by (" ") or (' ')
"Hello world"
# Out:
# 'Hello world'

# %%
first_name = 'Elon'
last_name = 'Musk'

first_name + ' ' + last_name
# Out:
# 'Elon Musk'

# %%
first_name
# Out:
# 'Elon'

# %%
'Python' * 10
# Out:
# 'PythonPythonPythonPythonPythonPythonPythonPythonPythonPython'

# %%
'Python ' * 10
# Out:
# 'Python Python Python Python Python Python Python Python Python Python '

# %%
'Python'.upper()
# Out:
# 'PYTHON'

# %%
'PyThon'.lower()
# Out:
# 'python'

# %%
'python'.capitalize()
# Out:
# 'Python'

# %%
'PyThon'.swapcase()
# Out:
# 'pYtHON'

# %%
'I am learning python'.count('a')
# Out:
# 2

# %%
'I am learning python'.replace('a','e')
# Out:
# 'I em leerning python'

# %%
'      Aku suka belajar Python        '.strip() #trim
# Out:
# 'Aku suka belajar Python'
